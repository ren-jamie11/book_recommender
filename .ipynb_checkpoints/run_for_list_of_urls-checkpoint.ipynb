# %%
from BookScraper import *
import pandas as pd
import numpy as np

import time


file = 'book_urls/Psychology.txt'

def get_urls_from_txt_file(file):
    with open(file, 'r') as file:
        urls = file.readlines()

    urls = [url.strip() for url in urls]
    return urls

urls = get_urls_from_txt_file(file)
n = 5

# %%
def book_data_generator():
    for i, url in enumerate(urls[:n]):
        print("Parsing url", url)
    
        start_time = time.time()  # Start time for each iteration
    
        book = BookMetaData(url)
    
        # metadata
        book.get_metadata()
        book_metadata = book.retrieve_metadata()
    
        # reviews
        book.get_review_info()
        book_review_dict = book.retrieve_reviews()
    
        end_time = time.time()  # End time for each iteration
        loop_time = end_time - start_time  # Time taken for this iteration
        print(f"Time taken for iteration {i}: {loop_time:.2f} seconds")
        print()
    
        yield book_metadata, book_review_dict

# %%
book_data_gen = book_data_generator()

book_metadatas = [dict()] * n
book_reviews = []

for i, data in enumerate(book_data_gen):
    book_metadata, book_review_dict = data
    
    book_metadatas[i] = book_metadata
    book_reviews.extend(book_review_dict)
# Out:
# Parsing url https://www.goodreads.com/book/show/11468377-thinking-fast-and-slow
# Time taken for iteration 0: 2.56 seconds
#
# Parsing url https://www.goodreads.com/book/show/4069.Man_s_Search_for_Meaning
# Time taken for iteration 1: 2.45 seconds
#
# Parsing url https://www.goodreads.com/book/show/8520610-quiet
# Time taken for iteration 2: 2.42 seconds
#
# Parsing url https://www.goodreads.com/book/show/18693771-the-body-keeps-the-score
# Error getting user_rating: Could not find rating_text (aria-label) from review shelf
# Time taken for iteration 3: 2.19 seconds
#
# Parsing url https://www.goodreads.com/book/show/28815.Influence
# Time taken for iteration 4: 2.54 seconds

# %%
book_metadata_df = pd.DataFrame(book_metadatas)
book_review_df = pd.DataFrame(book_reviews)

# %%
book_metadata_df.head()
# Out:
#                                                title               author  \
# 0                            Thinking, Fast and Slow      Daniel Kahneman
# 1                           Man’s Search for Meaning     Viktor E. Frankl
# 2  Quiet: The Power of Introverts in a World That...           Susan Cain
# 3  The Body Keeps the Score: Brain, Mind, and Bod...  Bessel van der Kolk
# 4            Influence: The Psychology of Persuasion   Robert B. Cialdini
#
#                                               genres  page_count publish_date  \
# 0  [Nonfiction, Psychology, Self Help, Business, ...         499   2011-10-25
# 1  [Nonfiction, Psychology, Philosophy, Self Help...         165   1946-01-01
# 2  [Nonfiction, Psychology, Self Help, Audiobook,...         333   2012-01-24
# 3  [Nonfiction, Psychology, Self Help, Mental Hea...         464   2014-06-12
# 4  [Psychology, Business, Nonfiction, Self Help, ...         320   1984-01-01
#
#    rating  num_ratings  num_reviews  five_stars  four_stars  three_stars  \
# 0    4.17       552918        18458      257897      177715        84168
# 1    4.37       811052        44984      453084      243473        88363
# 2    4.08       460783        30740      183556      169177        78341
# 3    4.37       242631        19182      134215       74548        25788
# 4    4.22       167751         6052       81876       53297        23337
#
#    two_stars  one_star
# 0      21767     11371
# 1      17670      8462
# 2      19374     10335
# 3       5584      2496
# 4       5914      3327

# %%
book_review_df
# Out:
#                                                 title  \
# 0                             Thinking, Fast and Slow
# 1                             Thinking, Fast and Slow
# 2                             Thinking, Fast and Slow
# 3                             Thinking, Fast and Slow
# 4                             Thinking, Fast and Slow
# 5                             Thinking, Fast and Slow
# 6                             Thinking, Fast and Slow
# 7                             Thinking, Fast and Slow
# 8                             Thinking, Fast and Slow
# 9                             Thinking, Fast and Slow
# 10                           Man’s Search for Meaning
# 11                           Man’s Search for Meaning
# 12                           Man’s Search for Meaning
# 13                           Man’s Search for Meaning
# 14                           Man’s Search for Meaning
# 15                           Man’s Search for Meaning
# 16                           Man’s Search for Meaning
