# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

i = 12

ex_books = pd.read_parquet(f"group_{i}_new_books_data.parquet")
ex_reviews = pd.read_parquet(f"group_{i}_new_books_reviews.parquet")

# %%
ex_books
# Out:
#                                                  title  \
# 0    The Atlas of Languages: The Origin and Develop...
# 1    Ghost Boy: My Miraculous Escape from a Life Lo...
# 2    Living Emunah: Achieving A Life of Serenity th...
# 3    I Dared to Call Him Father: The Miraculous Sto...
# 4    The New Strong's Exhaustive Concordance of the...
# ..                                                 ...
# 495                  The Girl Who Fell Beneath the Sea
# 496                                    A Ruin of Roses
# 497                                         Below Zero
# 498                                  Forever After All
# 499                                    The Other Woman
#
#                       author  \
# 0    Bernard Comrie (Editor)
# 1           Martin Pistorius
# 2               David Ashear
# 3             Bilquis Sheikh
# 4               James Strong
# ..                       ...
# 495                  Axie Oh
# 496              K.F. Breene
# ...
