# %%
from BookScraper import *

import pandas as pd
import numpy as np
import time


file = 'book_urls/Psychology.txt'

def get_urls_from_txt_file(file):
    with open(file, 'r') as file:
        urls = file.readlines()

    urls = [url.strip() for url in urls]
    return urls

urls = get_urls_from_txt_file(file)
n = 5

# %%
def book_data_generator(n):
    for i, url in enumerate(urls[:n]):
        print("Parsing url", url)
    
        start_time = time.time()  # Start time for each iteration
    
        book = BookMetaData(url)
    
        # metadata
        book.get_metadata()
        book_metadata = book.retrieve_metadata()
    
        # reviews
        book.get_review_info()
        book_review_dict = book.retrieve_reviews()
    
        end_time = time.time()  # End time for each iteration
        loop_time = end_time - start_time  # Time taken for this iteration
        print(f"Time taken for iteration {i}: {loop_time:.2f} seconds")
        print()
    
        yield book_metadata, book_review_dict

# %%
book_data_gen = book_data_generator(3)

book_metadatas = [dict()] * n
book_reviews = []

for i, data in enumerate(book_data_gen):
    book_metadata, book_review_dict = data
    
    book_metadatas[i] = book_metadata
    book_reviews.extend(book_review_dict)
# Out:
# Parsing url https://www.goodreads.com/book/show/11468377-thinking-fast-and-slow
# Time taken for iteration 0: 2.41 seconds
#
# Parsing url https://www.goodreads.com/book/show/4069.Man_s_Search_for_Meaning
# Time taken for iteration 1: 2.29 seconds
#
# Parsing url https://www.goodreads.com/book/show/8520610-quiet
# Time taken for iteration 2: 2.33 seconds

# %%
book_metadata_df = pd.DataFrame(book_metadatas)
book_review_df = pd.DataFrame(book_reviews)

# %%
book_metadata_df
# Out:
#                                                title            author  \
# 0                            Thinking, Fast and Slow   Daniel Kahneman
# 1                           Man’s Search for Meaning  Viktor E. Frankl
# 2  Quiet: The Power of Introverts in a World That...        Susan Cain
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#                                               genres  page_count publish_date  \
# 0  [Nonfiction, Psychology, Self Help, Business, ...       499.0   2011-10-25
# 1  [Nonfiction, Psychology, Philosophy, Self Help...       165.0   1946-01-01
# 2  [Nonfiction, Psychology, Self Help, Audiobook,...       333.0   2012-01-24
# 3                                                NaN         NaN          NaT
# 4                                                NaN         NaN          NaT
#
#    rating  num_ratings  num_reviews  five_stars  four_stars  three_stars  \
# 0    4.17     552919.0      18458.0    257898.0    177716.0      84167.0
# 1    4.37     811062.0      44985.0    453090.0    243476.0      88364.0
# 2    4.08     460789.0      30740.0    183559.0    169180.0      78341.0
# 3     NaN          NaN          NaN         NaN         NaN          NaN
# 4     NaN          NaN          NaN         NaN         NaN          NaN
#
#    two_stars  one_star
# 0    21767.0   11371.0
# 1    17670.0    8462.0
# 2    19374.0   10335.0
# 3        NaN       NaN
# 4        NaN       NaN

# %%
book_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         3 non-null      object
#  1   author        3 non-null      object
#  2   genres        3 non-null      object
#  3   page_count    3 non-null      float64
#  4   publish_date  3 non-null      datetime64[ns]
#  5   rating        3 non-null      float64
#  6   num_ratings   3 non-null      float64
#  7   num_reviews   3 non-null      float64
#  8   five_stars    3 non-null      float64
#  9   four_stars    3 non-null      float64
#  10  three_stars   3 non-null      float64
#  11  two_stars     3 non-null      float64
#  12  one_star      3 non-null      float64
# dtypes: datetime64[ns](1), float64(9), object(3)
# memory usage: 652.0+ bytes

# %%
book_review_df
# Out:
#                                                 title  \
# 0                             Thinking, Fast and Slow
# 1                             Thinking, Fast and Slow
# 2                             Thinking, Fast and Slow
# 3                             Thinking, Fast and Slow
# 4                             Thinking, Fast and Slow
# 5                             Thinking, Fast and Slow
# 6                             Thinking, Fast and Slow
# 7                             Thinking, Fast and Slow
# 8                             Thinking, Fast and Slow
# 9                             Thinking, Fast and Slow
# 10                           Man’s Search for Meaning
# 11                           Man’s Search for Meaning
# 12                           Man’s Search for Meaning
# 13                           Man’s Search for Meaning
# 14                           Man’s Search for Meaning
# 15                           Man’s Search for Meaning
# 16                           Man’s Search for Meaning
# 17                           Man’s Search for Meaning
# 18                           Man’s Search for Meaning
# 19                           Man’s Search for Meaning
# 20  Quiet: The Power of Introverts in a World That...
# 21  Quiet: The Power of Introverts in a World That...
# 22  Quiet: The Power of Introverts in a World That...
# 23  Quiet: The Power of Introverts in a World That...
# 24  Quiet: The Power of Introverts in a World That...
# 25  Quiet: The Power of Introverts in a World That...
# 26  Quiet: The Power of Introverts in a World That...
# 27  Quiet: The Power of Introverts in a World That...
# 28  Quiet: The Power of Introverts in a World That...
# 29  Quiet: The Power of Introverts in a World That...
#
#                                               user_id  rating
# 0                                       175635-trevor       5
# 1                             965207-robert-schneider       5
# 2                                         671574-john       1
# 3                                1188122-kara-babcock       3
# 4   22189348-adina-notifications-back-log-out-clea...       5
# 5             70395042-fergus-weaver-of-autistic-webs       5
# 6                                      14972518-vijai       4
# 7                                      21348532-liong       4
# 8                              4369435-r-j-kamaladasa       5
# 9                             614778-ahmad-sharabiani       4
# 10                                      957217-laurel       5
# 11                                       140090-frank       5
# 12                            1237196-petra-in-sydney       5
# 13                                 1651956-riku-sayuj       3
# 14               42130592-chai-thelibrairie-on-tiktok       5
# 15                                            2849038       5
# 16                            48650982-always-pouting       4
# 17                                    1381728-maxwell       3
# 18                16958299-dr-appu-sasidharan-dasfill       5
# 19                              48402276-mohammed-ali       5
# 20                                        94602-kelly       3
# 21                                  4622890-emily-may       4
# 22                                      9653496-hanne       4
# 23                1085121-stephanie-eff-your-feelings       4
# 24            70395042-fergus-weaver-of-autistic-webs       4
# 25                                27788046-sean-barrs       5
# 26                                      1713956-manny       4
# 27                                           70494092       4
# 28                16958299-dr-appu-sasidharan-dasfill       2
# 29     58160628-emily-books-with-emily-fox-on-youtube       4
