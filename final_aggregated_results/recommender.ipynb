# %%
import sys
import warnings

warnings.filterwarnings('ignore')
sys.path.append(r"C:\Users\13477\Desktop\New Adventure\Goodreads\goodreads_prod")

from static import *
from UserScraper import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

from joblib import Parallel, delayed
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException

def process_raw_books(books):
    res = books.drop_duplicates(subset = ['title'])
    res = res.dropna()
    return res

def process_raw_reviews(reviews):
    """ Make sure each user only reviews a book once """
    res = reviews.drop_duplicates(subset = ['title', 'user_id'], keep = 'first')
    res = res.dropna()

    return res

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# #### Load data from parquets (scraped from goodreads)

# %%
# 16,578 books, 476,364 reviews, 9466 complete user profiles 
all_books = pd.read_parquet("all_books_final.parquet")
all_books = process_raw_books(all_books)
all_books_ratings = all_books[['title', 'rating', 'num_ratings']]

all_reviews = pd.read_parquet("english_reviews_final.parquet")
all_reviews = process_raw_reviews(all_reviews)

users_data = pd.read_parquet("users_data_final.parquet")

all_books = all_books[all_books.title.isin(all_reviews.title)]
users_with_data = users_data.user_id.unique()

# %%
users_data['is_notable'] = users_data['is_best_reviewer'] | users_data['is_most_followed']
users_data[users_data.is_notable]
# Out:
#                                                 user_url  \
# 26     https://www.goodreads.com/user/show/28020639-i...
# 37     https://www.goodreads.com/user/show/35915119-a...
# 40     https://www.goodreads.com/user/show/46560610-b...
# 119    https://www.goodreads.com/user/show/15736557-l...
# 127    https://www.goodreads.com/user/show/59214246-s...
# ...                                                  ...
# 14540      https://www.goodreads.com/user/show/132812492
# 14541       https://www.goodreads.com/user/show/12543333
# 14587  https://www.goodreads.com/user/show/20234777-t...
# 14604  https://www.goodreads.com/user/show/18009940-dean
# 14608  https://www.goodreads.com/user/show/5069466-pa...
#
#                          user_id              name  num_ratings  avg_rating  \
# 26     28020639-iben-frederiksen  Iben Frederiksen          496        3.68
# 37        35915119-ashley-daviau     Ashley Daviau         2248        4.10
# 40              46560610-beatriz           Beatriz         1029        3.37
# 119          15736557-lynne-king        Lynne King          862        4.07
# 127           59214246-sara-lowe         Sara Lowe           81        4.12
# ...                          ...               ...          ...         ...
# 14540                  132812492         الف‌م‌ی‌ر           95        3.87
# 14541                   12543333              حماس          319        2.96
# 14587          20234777-tawallah          Tawallah         1624        3.36
# 14604              18009940-dean              Dean          558        4.51
# 14608        5069466-paul-mullen       Paul Mullen          129        3.52
#
#        num_reviews  is_best_reviewer  reviewer_rank  is_most_followed  \
# 26             308              True             55              True
# 37            2137              True             37             False
# 40             946              True              1              True
# 119            499              True              9              True
# 127             17              True             30              True
# ...            ...               ...            ...               ...
# 14540           34              True             90             False
# 14541          252              True             58             False
# 14587         1125              True              2             False
# 14604          533              True             58             False
# 14608          118              True             37             False
#
#        follow_rank  is_notable
# 26              24        True
# 37               0        True
# 40               9        True
# 119             41        True
# 127             41        True
# ...            ...         ...
# 14540            0        True
# 14541            0        True
# 14587            0        True
# 14604            0        True
# 14608            0        True
#
# [1829 rows x 11 columns]

# %% [markdown]
# ### Book rating normalizer

# %%
def book_rating_std(mean_rating, num_ratings, five_stars, four_stars, three_stars, two_stars, one_star):
    if num_ratings <= 1:
        return 0  # or raise an error, depending on your use case
    
    rating_values = [5, 4, 3, 2, 1]
    rating_freqs = [five_stars, four_stars, three_stars, two_stars, one_star]
    
    numerator = sum(f * (v - mean_rating) ** 2 for v, f in zip(rating_values, rating_freqs))
    var = numerator / (num_ratings - 1)
    
    return np.sqrt(var)

def rating_zscore(r, mean_ratings, std_ratings):
    res = (r - mean_ratings)/std_ratings
    return res

def construct_book_rating_stats(all_books):
    books_rating_stats = all_books[['title', 'rating', 'num_ratings', 'five_stars', 'four_stars', 'three_stars', 'two_stars', 'one_star']]
    books_rating_stats = books_rating_stats.rename(columns = {'rating': 'mean_rating'})
    books_rating_stats = books_rating_stats.set_index('title')

    # Apply to DataFrame
    books_rating_stats['rating_std'] = books_rating_stats.apply(
        lambda row: book_rating_std(
            row['mean_rating'],
            row['num_ratings'],
            row['five_stars'],
            row['four_stars'],
            row['three_stars'],
            row['two_stars'],
            row['one_star']
        ),
        axis=1
    )

    # get zscore
    mean_ratings = books_rating_stats.mean_rating.values
    std_ratings = books_rating_stats.rating_std.values
    
    for i in range(5,0,-1):
        books_rating_stats[f'{i}_zscore'] = rating_zscore(i, mean_ratings, std_ratings)

    return books_rating_stats

# %%
books_rating_stats = pd.read_parquet('book_rating_stats.parquet')
books_rating_stats.head()
# Out:
#                                                title  mean_rating  \
# 0                                     Ways of Seeing         3.93
# 1                                   The Story of Art         3.96
# 2  Steal Like an Artist: 10 Things Nobody Told Yo...         3.96
# 3     The New Drawing on the Right Side of the Brain         3.87
# 4  The Artist's Way: A Spiritual Path to Higher C...         3.95
#
#    num_ratings  five_stars  four_stars  three_stars  two_stars  one_star  \
# 0       409891      180540      104714        68443      27972     28222
# 1       441491      205333      104059        73087      29183     29829
# 2       317933      137177       87225        55875      18949     18707
# 3       368384      157253       89353        66495      26330     28953
# 4       115356       49092       32508        19489       7580      6687
#
#    rating_std  5_zscore  4_zscore  3_zscore  2_zscore  1_zscore
# 0    1.222802  0.875040  0.057246 -0.760548 -1.578342 -2.396137
# 1    1.225518  0.848621  0.032639 -0.783343 -1.599324 -2.415306
# 2    1.171995  0.887376  0.034130 -0.819116 -1.672363 -2.525609
# 3    1.258219  0.898095  0.103321 -0.691453 -1.486228 -2.281002
# 4    1.173334  0.894886  0.042614 -0.809659 -1.661931 -2.514204

# %% [markdown]
# #### Label reviews with genres

# %%
def construct_book_genre_labels(all_books):
    mlb = MultiLabelBinarizer(classes=genres)
    genre_matrix = mlb.fit_transform(all_books['genres'])
    genre_df = pd.DataFrame(genre_matrix, columns=mlb.classes_, index=all_books.index)
    genre_labels = pd.concat([all_books[['title']], genre_df], axis=1)

    return genre_labels

def label_reviews_with_genre(all_reviews, genre_labels):
    all_labeled_reviews = all_reviews.merge(
        genre_labels, 
        on='title', 
        how='inner'
    )

    all_labeled_reviews = all_labeled_reviews.drop_duplicates(subset=['title', 'user_id', 'rating'])
    return all_labeled_reviews

genre_labels = construct_book_genre_labels(all_books)
all_labeled_reviews = label_reviews_with_genre(all_reviews, genre_labels)

# %% [markdown]
# #### User genre counts
#
# For each user (col), how many books from each genre (row) have they read?

# %%
def get_user_genre_counts(reviews):
    
    user_genre_counts = reviews.groupby('user_id')[genres].sum().T  # genres as index
    num_reviews_by_user = reviews.groupby('user_id')['title'].count()
    user_genre_pct = user_genre_counts.div(num_reviews_by_user, axis = 1)

    return user_genre_counts, user_genre_pct

# %%
user_genre_counts, user_genre_pct = get_user_genre_counts(all_labeled_reviews)

# %%
compact_labeled_reviews = all_labeled_reviews[all_labeled_reviews.user_id.isin(users_with_data)]
compact_user_genre_count, compact_genre_pct = get_user_genre_counts(compact_labeled_reviews)

# %% [markdown]
# #### User item matrix

# %%
def construct_user_item_matrix(reviews):
    reviews_grouped = reviews.groupby(['user_id', 'title'])['rating'].mean().reset_index()
    user_item_matrix = reviews_grouped.pivot(index='user_id', columns='title', values='rating')
    user_item_matrix = user_item_matrix.fillna(0)

    return user_item_matrix

def condense_user_item_matrix(user_item_matrix, n = 3):

    filtered_matrix = user_item_matrix[user_item_matrix.astype(bool).sum(axis=1) >= n]
    filtered_matrix = filtered_matrix.loc[:, filtered_matrix.astype(bool).sum(axis=0) >= n]

    return filtered_matrix

def center_user_item_matrix(user_item_matrix):
    """ Assumes users are rows
        Subtracts each user's rating by its mean ratings 
        (computed from non zero ratings)
    """
    
    tmp = user_item_matrix.replace(0, np.NaN)
    tmp_means = tmp.mean(axis = 1)

    new_tmp = tmp.sub(tmp_means, axis = 0)
    new_tmp = new_tmp.fillna(0)

    return new_tmp

# %%
main_user_item_matrix = construct_user_item_matrix(compact_labeled_reviews)

# %%
def get_title_zscore_dict(ex_title, books_rating_stats = books_rating_stats):
    z_score_cols = ['5_zscore', '4_zscore', '3_zscore', '2_zscore', '1_zscore']
    rating_values = [5, 4, 3, 2, 1]

    title_zscores = books_rating_stats[books_rating_stats.title == ex_title][z_score_cols].values.ravel()
    res_dict = {r: z for r, z in zip(rating_values, title_zscores)}

    return res_dict

def get_zscore_for_title(user_item_matrix, title):
    zscore_dict = get_title_zscore_dict(title)
    
    title_col = user_item_matrix[title]
    title_col = title_col.replace(zscore_dict).where(title_col != 0, 0)

    return title_col

# %%
# Apply to every title (column) in the DataFrame
zscore_matrix = pd.read_parquet('zscore_normed_user_item_matrix.parquet')

# %%
centered_zscore_matrix = center_user_item_matrix(zscore_matrix)

# %% [markdown]
# ### Genre recommender

# %% [markdown]
# #### Z-score normalized user item matrix

# %%
my_genre = 'Philosophy'

# %% [markdown]
# #### Find top reviewers for genre

# %%
def get_score(count, pct, alpha = 1):
    score = count * pct**alpha
    return score

def user_read_counts_for_genre(my_genre, user_genre_counts, user_genre_pct):
    genre_review_count_ranked = user_genre_counts.loc[my_genre, :].sort_values(ascending = False)
    genre_pct_of_reviews_ranked = user_genre_pct.loc[my_genre, :].sort_values(ascending = False)

    res = pd.DataFrame({"review_count": genre_review_count_ranked, "review_pct": genre_pct_of_reviews_ranked})
    return res

def get_genre_ranker(my_genre, user_genre_counts, user_genre_pct, alpha = 1):
    user_read_counts = user_read_counts_for_genre(my_genre, user_genre_counts, user_genre_pct)
    user_read_counts['score'] = get_score(user_read_counts['review_count'], user_read_counts['review_pct'], alpha = alpha)

    user_read_counts = user_read_counts[user_read_counts.review_count > 0]
    user_read_counts = user_read_counts.sort_values(by = 'score', ascending = False)
    return user_read_counts

def get_top_n_reviewers(ranker, n):
    top_n = ranker.head(n)
    top_n['score_normed'] = top_n['score']/np.sum(top_n['score'])

    return top_n

# %% [markdown]
# #### Suggest books from top reviewers

# %%
def filter_reviews_for_genre(my_genre, labeled_reviews):
    reviews_filtered = labeled_reviews[labeled_reviews[my_genre] == 1]
    reviews_filtered = reviews_filtered.drop(columns = my_genre)
    return reviews_filtered[['title', 'user_id', 'rating']]

def get_expert_user_item_matrix(user_item_matrix, experts):
    expert_user_item_matrix =  user_item_matrix[user_item_matrix.index.isin(experts)]
    expert_user_item_matrix = expert_user_item_matrix.loc[experts]

    return expert_user_item_matrix


def adjust_expert_user_item_matrix(expert_user_item_matrix, adjust_value = 3):
    """ Adjust ratings downward by adjust_value"""
    adjusted_expert_user_item_matrix = expert_user_item_matrix.where(expert_user_item_matrix == 0, expert_user_item_matrix - adjust_value)
    return adjusted_expert_user_item_matrix

def lookup_rating(user_item_matrix, user_id, book_name):
    return user_item_matrix.loc[user_id, book_name]

def ratings_of_those_who_read(book_name, top_n_reviewers, expert_user_item_matrix):
    experts = top_n_reviewers.index
    amount_of_say = top_n_reviewers['score_normed']
    
    wavgs = pd.DataFrame(amount_of_say)
    wavgs['book_rating'] = [lookup_rating(expert_user_item_matrix, u, book_name) for u in experts]
    wavgs = wavgs[wavgs.book_rating != 0]

    return wavgs

def avg_expert_rating(book_name, top_n_reviewers, expert_user_item_matrix):
    amount_of_say = top_n_reviewers['score_normed']
    experts = top_n_reviewers.index
    
    wavgs = ratings_of_those_who_read(book_name, top_n_reviewers, expert_user_item_matrix)
    res = np.dot(wavgs['score_normed'], wavgs['book_rating'])/np.sum(wavgs['score_normed'])
    
    return res, len(wavgs)

def get_expert_ratings(expert_user_item_matrix, top_n_reviewers):
    """ sum(amount of say * rating) for everyone who rated the book for each book
    
    The more people who interacted...the more the score will be affected
    E.g. 10 people who rated positive > 5 people who rated positive
    """
    amount_of_say = top_n_reviewers['score_normed']

    expert_ratings = expert_user_item_matrix.T.dot(amount_of_say)
    expert_ratings= pd.DataFrame(expert_ratings)
    
    expert_ratings.columns = ['expert_metric']
    expert_ratings = expert_ratings.drop_duplicates()
    expert_ratings = expert_ratings.sort_values(by = 'expert_metric', ascending = False)

    return expert_ratings

def merge_expert_with_overall(expert_rating, all_books_rating, num_reviewers = 50):
    merged = expert_rating.merge(all_books_ratings, left_index=True, right_on='title', how='inner')
    merged = merged.set_index('title')
    
    merged = merged[['expert_wavg_rating', f'experts_who_read_out_of_{num_reviewers}', 
                     'expert_metric', 'rating', 'num_ratings']]

    return merged

# %%
def top_n_genre_expert_recommendations(my_genre, all_labeled_reviews, user_genre_counts, user_genre_pct, 
                                       num_reviewers = 50, how_many = 10, alpha = 1.2):
    # filter reviews from this genre and transform to user_item_matrix
    genre_filtered_reviews = filter_reviews_for_genre(my_genre, all_labeled_reviews)
    genre_user_item_matrix = construct_user_item_matrix(genre_filtered_reviews)
    genre_user_item_matrix = condense_user_item_matrix(genre_user_item_matrix)

    # use top reviewers to decide which books to recommend
    genre_ranker = get_genre_ranker(my_genre, user_genre_counts, user_genre_pct, alpha = alpha)
    
    top_n = get_top_n_reviewers(genre_ranker, num_reviewers)
    experts = top_n.index
    amount_of_say = top_n['score_normed']


    """ maybe write this as another atom func """
    # user_item_matrix for top reviewers of this genre
    expert_user_item_matrix = get_expert_user_item_matrix(genre_user_item_matrix, top_n.index)
    adjusted_expert_user_item_matrix = center_user_item_matrix(expert_user_item_matrix)

    adjusted_expert_ratings = get_expert_ratings(adjusted_expert_user_item_matrix, top_n)
    adjusted_expert_ratings[['expert_wavg_rating',f'experts_who_read_out_of_{num_reviewers}']] = [avg_expert_rating(book, top_n, expert_user_item_matrix) for book in adjusted_expert_ratings.index]
    # adjusted_expert_ratings['experts_who_read'] = adjusted_expert_ratings['experts_who_read']/num_reviewers
    # adjusted_expert_ratings['experts_who_read'] = adjusted_expert_ratings['experts_who_read'].apply(lambda x: f"{x * 100:.0f}%")

    adjusted_expert_ratings = adjusted_expert_ratings.round(2)
    adjusted_expert_ratings = adjusted_expert_ratings[['expert_wavg_rating', f'experts_who_read_out_of_{num_reviewers}', 'expert_metric']]

    best = adjusted_expert_ratings.head(how_many)
    controversial = adjusted_expert_ratings.tail(how_many).sort_values(by = 'expert_metric')
    
    best = merge_expert_with_overall(best, all_books_ratings)
    controversial = merge_expert_with_overall(controversial, all_books_ratings)

    return best, controversial, top_n

# %%
best, controversial, your_reviewers = top_n_genre_expert_recommendations('Philosophy', all_labeled_reviews,
                                                         user_genre_counts, user_genre_pct)

# %%
best
# Out:
#                                                     expert_wavg_rating  \
# title
# In Search of Lost Time, Volume 1: The Way by Sw...                4.88
# Tractatus Logico Philosophicus                                    4.66
# The Symposium                                                     4.60
# Phenomenology of Spirit                                           4.70
# Swann's Way                                                       4.87
# Introduction to Metaphysics                                       4.61
# An Enquiry Concerning Human Understanding                         4.24
# The Elementary Forms of the Religious Life                        4.30
# Darwin's Dangerous Idea: Evolution and the Mean...                4.47
# Capital: A Critique of Political Economy Volume 1                 4.23
#
#                                                     experts_who_read_out_of_50  \
# title
# In Search of Lost Time, Volume 1: The Way by Sw...                        10.0
# Tractatus Logico Philosophicus                                             8.0
# The Symposium                                                              9.0
# Phenomenology of Spirit                                                    8.0
# Swann's Way                                                                9.0
# Introduction to Metaphysics                                                6.0
# An Enquiry Concerning Human Understanding                                  5.0
# The Elementary Forms of the Religious Life                                 4.0
# Darwin's Dangerous Idea: Evolution and the Mean...                         5.0
# Capital: A Critique of Political Economy Volume 1                          8.0
#
#                                                     expert_metric  rating  \
# title
# In Search of Lost Time, Volume 1: The Way by Sw...           0.19    4.15
# Tractatus Logico Philosophicus                               0.18    4.10
# The Symposium                                                0.17    4.09
# Phenomenology of Spirit                                      0.17    3.96
# Swann's Way                                                  0.17    4.15
# Introduction to Metaphysics                                  0.16    4.03
# An Enquiry Concerning Human Understanding                    0.16    3.94
# The Elementary Forms of the Religious Life                   0.13    3.93
# Darwin's Dangerous Idea: Evolution and the Mean...           0.13    4.07
# Capital: A Critique of Political Economy Volume 1            0.13    4.09
#
#                                                     num_ratings
# title
# In Search of Lost Time, Volume 1: The Way by Sw...        65076
# Tractatus Logico Philosophicus                            21407
# The Symposium                                             83867
# Phenomenology of Spirit                                   19718
# Swann's Way                                               65076
# Introduction to Metaphysics                                4260
# An Enquiry Concerning Human Understanding                 21653
# The Elementary Forms of the Religious Life                 3660
# Darwin's Dangerous Idea: Evolution and the Mean...        16774
# Capital: A Critique of Political Economy Volume 1         22854

# %%
controversial
# Out:
#                                                     expert_wavg_rating  \
# title
# Cosmos and Psyche: Intimations of a New World View                1.60
# The Closing of the American Mind                                  2.11
# Being and Nothingness                                             3.27
# Industrial Society and Its Future                                 1.33
# 12 Rules for Life: An Antidote to Chaos                           1.91
# The Varieties of Religious Experience                             2.90
# The Road to Serfdom                                               2.02
# Enlightenment Now: The Case for Reason, Science...                2.55
# The Teachings of Don Juan: A Yaqui Way of Knowl...                2.59
# A Study of History, Abridgement of Vols 1-6                       1.72
#
#                                                     experts_who_read_out_of_50  \
# title
# Cosmos and Psyche: Intimations of a New World View                         3.0
# The Closing of the American Mind                                           5.0
# Being and Nothingness                                                     10.0
# Industrial Society and Its Future                                          4.0
# 12 Rules for Life: An Antidote to Chaos                                    6.0
# The Varieties of Religious Experience                                      8.0
# The Road to Serfdom                                                        5.0
# Enlightenment Now: The Case for Reason, Science...                         3.0
# The Teachings of Don Juan: A Yaqui Way of Knowl...                         4.0
# A Study of History, Abridgement of Vols 1-6                                2.0
#
#                                                     expert_metric  rating  \
# title
# Cosmos and Psyche: Intimations of a New World View          -0.25    4.25
# The Closing of the American Mind                            -0.25    3.76
# Being and Nothingness                                       -0.21    3.99
# Industrial Society and Its Future                           -0.21    3.86
# 12 Rules for Life: An Antidote to Chaos                     -0.19    3.92
# The Varieties of Religious Experience                       -0.19    4.01
# The Road to Serfdom                                         -0.18    4.15
# Enlightenment Now: The Case for Reason, Science...          -0.18    4.20
# The Teachings of Don Juan: A Yaqui Way of Knowl...          -0.18    3.94
# A Study of History, Abridgement of Vols 1-6                 -0.18    4.10
#
#                                                     num_ratings
# title
# Cosmos and Psyche: Intimations of a New World View         1213
# The Closing of the American Mind                           5822
# Being and Nothingness                                     33625
# Industrial Society and Its Future                         11534
# 12 Rules for Life: An Antidote to Chaos                  252695
# The Varieties of Religious Experience                     12570
# The Road to Serfdom                                       25121
# Enlightenment Now: The Case for Reason, Science...        31404
# The Teachings of Don Juan: A Yaqui Way of Knowl...        44399
# A Study of History, Abridgement of Vols 1-6                 518

# %%
your_reviewers
# Out:
#                                          review_count  review_pct      score  \
# user_id
# 6243880-beauregard-bottomley                       91    0.710938  60.428122
# 175635-trevor                                     125    0.428082  45.158822
# 60074558-xander                                    54    0.857143  44.880492
# 25683251                                           78    0.537931  37.065215
# 1651956-riku-sayuj                                 93    0.444976  35.195484
# 14046996-roy-lotz                                  94    0.429224  34.068133
# 42133960-peiman-e-iran                             62    0.601942  33.717631
# 3897817-morgan-blackledge                          69    0.526718  31.969986
# 974210-erik-graff                                  83    0.448649  31.722378
# 108995717-dan                                      32    0.941176  29.754678
# 29002534-valeriu-gherghel                          83    0.412935  28.716832
# 614778-ahmad-sharabiani                           238    0.170609  28.508887
# 117399210-lu-s                                    117    0.293233  26.843641
# 70395042-fergus-weaver-of-autistic-webs            95    0.347985  26.766819
# 2105523-j-d-steens                                 34    0.755556  24.288383
# 5610133-sologdin                                   40    0.634921  23.191205
# 8663556-hayatem                                    30    0.769231  21.897233
# 1045774-mehrsa                                     94    0.285714  20.904809
# 1713956-manny                                      97    0.271709  20.309347
# 112699911-orhan-pelinkovic                         33    0.660000  20.043182
# 24749419-vui-l-n                                   23    0.884615  19.853324
# 11509598-alex-lee                                  19    0.950000  17.865778
# 7422525-scriptor-ignotus                           28    0.682927  17.717688
# 1843184-szplug                                     36    0.537313  17.083456
# 13716226-murtaza                                   39    0.500000  16.975736
# 9517361-blaine-snow                                19    0.904762  16.849801
# 17744555-blackoxford                               70    0.290456  15.877980
# 56673559-ipsa                                      18    0.900000  15.862203
# 21575078-flo                                       35    0.514706  15.773897
# 4024817-otto-lehto                                 20    0.714286  13.355998
# 30131258-alina-w                                   17    0.809524  13.192420
# 31567333-erick                                     17    0.809524  13.192420
# 3688618-steve-woods                                16    0.842105  13.018461
# 1258773-douglas-wilson                             43    0.361345  12.675767
# 1339246-gendou                                     21    0.656250  12.667837
# 35434974-kevin                                     36    0.409091  12.316471
# 31207039                                           22    0.611111  12.183355
# 10093848-david-withun                              15    0.833333  12.052406
# 14824621-elena                                     12    1.000000  12.000000
# 34749978-turbulent-architect                       12    1.000000  12.000000
# 108352571-jcjbergman                               12    1.000000  12.000000
# 79765515-prerna                                    28    0.491228  11.931577
# 8711518-ahmed-oraby                                19    0.678571  11.930765
# 88691269-sajid                                     14    0.875000  11.927178
# 6423134-bernie-gourley                             16    0.761905  11.545183
# 16783645-ahmad-ebaid                               21    0.583333  10.998145
# 60620372-t                                         13    0.866667  10.948783
# 52918291-aung-sett-kyaw-min                        12    0.923077  10.901010
# 2294090-darwin8u                                   68    0.215190  10.762053
# 68029956-paul-h                                    22    0.550000  10.736381
#
#                                          score_normed
# user_id
# 6243880-beauregard-bottomley                 0.058576
# 175635-trevor                                0.043774
# 60074558-xander                              0.043505
# 25683251                                     0.035929
# 1651956-riku-sayuj                           0.034116
# 14046996-roy-lotz                            0.033024
# 42133960-peiman-e-iran                       0.032684
# 3897817-morgan-blackledge                    0.030990
# 974210-erik-graff                            0.030750
# 108995717-dan                                0.028842
# 29002534-valeriu-gherghel                    0.027836
# 614778-ahmad-sharabiani                      0.027635
# 117399210-lu-s                               0.026021
# 70395042-fergus-weaver-of-autistic-webs      0.025946
# 2105523-j-d-steens                           0.023544
# 5610133-sologdin                             0.022480
# 8663556-hayatem                              0.021226
# 1045774-mehrsa                               0.020264
# 1713956-manny                                0.019687
# 112699911-orhan-pelinkovic                   0.019429
# 24749419-vui-l-n                             0.019245
# 11509598-alex-lee                            0.017318
# 7422525-scriptor-ignotus                     0.017175
# 1843184-szplug                               0.016560
# 13716226-murtaza                             0.016455
# 9517361-blaine-snow                          0.016333
# 17744555-blackoxford                         0.015391
# 56673559-ipsa                                0.015376
# 21575078-flo                                 0.015290
# 4024817-otto-lehto                           0.012947
# 30131258-alina-w                             0.012788
# 31567333-erick                               0.012788
# 3688618-steve-woods                          0.012619
# 1258773-douglas-wilson                       0.012287
# 1339246-gendou                               0.012279
# 35434974-kevin                               0.011939
# 31207039                                     0.011810
# 10093848-david-withun                        0.011683
# 14824621-elena                               0.011632
# 34749978-turbulent-architect                 0.011632
# 108352571-jcjbergman                         0.011632
# 79765515-prerna                              0.011566
# 8711518-ahmed-oraby                          0.011565
# 88691269-sajid                               0.011562
# 6423134-bernie-gourley                       0.011191
# 16783645-ahmad-ebaid                         0.010661
# 60620372-t                                   0.010613
# 52918291-aung-sett-kyaw-min                  0.010567
# 2294090-darwin8u                             0.010432
# 68029956-paul-h                              0.010407

# %% [markdown]
# ### User similarity recommender

# %%
user_id = '155041466'

# user_id = '153156500-michelle-lee'
base_url = 'https://www.goodreads.com/user/show/'
user_url = base_url+user_id

def get_user_info(url):
    user = UserMetaData(url, review_pages=4)
    user.get_metadata()

    user_metadata = user.retrieve_metadata()

    user.get_review_info()
    user_reviews = user.retrieve_reviews()

    return user_metadata, user_reviews

def review_coverage(user_reviews, all_books = all_books):
    coverage = len(user_reviews[user_reviews.title.isin(all_books.title)])/len(user_reviews)
    return coverage

# %%
def replace_zeros_with_nonzero_mean(arr):
    arr = arr.copy()  # avoid modifying original array
    non_zero_mean = arr[arr != 0].mean()
    print(non_zero_mean)
    arr[arr == 0] = non_zero_mean
    return arr

# %%
user_metadata, user_reviews = get_user_info(user_url)
user_reviews = pd.DataFrame(user_reviews)
user_reviews['rating'] = replace_zeros_with_nonzero_mean(user_reviews.rating.values)
# Out:
# 4.517241379310345

# %%
user_reviews.head()
# Out:
#      user_id                                    title_id  \
# 0  155041466             1052.The_Richest_Man_in_Babylon
# 1  155041466  4866.How_to_Stop_Worrying_and_Start_Living
# 2  155041466                               61439040-1984
# 3  155041466                51893.Thus_Spoke_Zarathustra
# 4  155041466                       6708.The_Power_of_Now
#
#                                                title  rating  votes
# 0                         The Richest Man in Babylon       4      0
# 1  How to Stop Worrying and Start Living: Time-Te...       4      0
# 2                                               1984       5      0
# 3                             Thus Spoke Zarathustra       4      0
# 4  The Power of Now: A Guide to Spiritual Enlight...       5      0

# %%
user_reviews
# Out:
#       user_id                                         title_id  \
# 0   155041466                  1052.The_Richest_Man_in_Babylon
# 1   155041466       4866.How_to_Stop_Worrying_and_Start_Living
# 2   155041466                                    61439040-1984
# 3   155041466                     51893.Thus_Spoke_Zarathustra
# 4   155041466                            6708.The_Power_of_Now
# 5   155041466                       857333.The_Art_of_Learning
# 6   155041466               612188.Memories_Dreams_Reflections
# 7   155041466                      30013.Prelude_to_Foundation
# 8   155041466                          13079982-fahrenheit-451
# 9   155041466                        1303.The_48_Laws_of_Power
# 10  155041466                                 28862.The_Prince
# 11  155041466                                  4214.Life_of_Pi
# 12  155041466                           202897.Foreign_Affairs
# 13  155041466                                 11989.The_Plague
# 14  155041466         4865.How_to_Win_Friends_Influence_People
# 15  155041466                              375802.Ender_s_Game
# 16  155041466                      5107.The_Catcher_in_the_Rye
# 17  155041466                             10534.The_Art_of_War
# 18  155041466                             5129.Brave_New_World
# 19  155041466                               49552.The_Stranger
# 20  155041466                    4069.Man_s_Search_for_Meaning
# 21  155041466                        7144.Crime_and_Punishment
# 22  155041466                                    44767458-dune
# 23  155041466                      12609433-the-power-of-habit
# 24  155041466                             18007564-the-martian
# 25  155041466             18143977-all-the-light-we-cannot-see
# 26  155041466                              17354208-relentless
# 27  155041466               24583.The_Adventures_of_Tom_Sawyer
# 28  155041466                       91950.The_Myth_of_Sisyphus
# 29  155041466                       30257963-12-rules-for-life
# 30  155041466                                35133922-educated
# 31  155041466                39330937-the-laws-of-human-nature
# 32  155041466                     40230101-the-mamba-mentality
# 33  155041466                           41721428-can-t-hurt-me
# 34  155041466                                   41795733-range
# 35  155041466  43708884-the-boy-the-mole-the-fox-and-the-horse
# 36  155041466                           50093704-in-five-years
# 37  155041466                    52578297-the-midnight-library
# 38  155041466                                     49350179-jfk
# 39  155041466                             52838315-greenlights
#
#                                                 title  rating  votes  \
# 0                          The Richest Man in Babylon       4      0
# 1   How to Stop Worrying and Start Living: Time-Te...       4      0
# 2                                                1984       5      0
# 3                              Thus Spoke Zarathustra       4      0
# 4   The Power of Now: A Guide to Spiritual Enlight...       5      0
# 5   The Art of Learning: A Journey in the Pursuit ...       5      0
# 6                       Memories, Dreams, Reflections       5      0
# 7                               Prelude to Foundation       5      0
# 8                                      Fahrenheit 451       5      0
# 9                                The 48 Laws of Power       4      0
# 10                                         The Prince       4      0
# 11                                         Life of Pi       4      0
# 12                                    Foreign Affairs       4      0
# 13                                         The Plague       3      0
# 14              How to Win Friends & Influence People       5      0
# 15                                       Ender’s Game       4      0
# 16                             The Catcher in the Rye       4      0
# 17                                     The Art of War       5      0
# 18                                    Brave New World       5      0
# 19                                       The Stranger       4      0
# 20                           Man’s Search for Meaning       5      0
# 21                               Crime and Punishment       4      0
# 22                                               Dune       5      0
# 23  The Power of Habit: Why We Do What We Do in Li...       5      0
# 24                                        The Martian       4      0
# 25                        All the Light We Cannot See       5      0
# 26      Relentless: From Good to Great to Unstoppable       4      0
# 27                       The Adventures of Tom Sawyer       4      0
# 28                               The Myth of Sisyphus       4      0
# 29            12 Rules for Life: An Antidote to Chaos       5      0
# 30                                           Educated       2      0
# 31                           The Laws of Human Nature       5      0
# 32                    The Mamba Mentality: How I Play       5      0
# 33  Can't Hurt Me: Master Your Mind and Defy the Odds       4      0
# 34  Range: Why Generalists Triumph in a Specialize...       4      0
# 35           The Boy, the Mole, the Fox and the Horse       5      0
# 36                                      In Five Years       4      0
# 37                               The Midnight Library       4      0
# 38  JFK: Coming Of Age In The American Century, 19...       5      0
# 39                                        Greenlights       4      0
#
#     zscore_normed_rating
# 0              -0.244134
# 1              -0.163792
# 2              -1.000000
# 3              -0.069174
# 4               0.811980
# 5              -1.000000
# 6               0.819219
# 7              -1.000000
# 8              -1.000000
# 9              -0.094543
# 10              0.160180
# 11              0.057560
# 12             -1.000000
# 13             -1.126337
# 14              0.796729
# 15             -1.000000
# 16              0.174699
# 17              1.071136
# 18              1.015549
# 19              0.111551
# 20              0.748640
# 21             -0.299382
# 22             -1.000000
# 23              0.943570
# 24             -0.526696
# 25              0.787745
# 26              0.036043
# 27              0.081118
# 28             -0.202869
# 29              0.925882
# 30             -3.171491
# 31              0.731672
# 32             -1.000000
# 33             -0.310766
# 34             -0.149324
# 35              0.563534
# 36              0.225752
# 37              0.020937
# 38              0.689994
# 39             -1.000000

# %% [markdown]
# ##### Compact user reviews

# %%
compact_labeled_reviews = all_labeled_reviews[all_labeled_reviews.user_id.isin(users_with_data)]
compact_user_genre_count, compact_genre_pct = get_user_genre_counts(compact_labeled_reviews)

# %%
genre_labels = construct_book_genre_labels(all_books)
all_labeled_reviews = label_reviews_with_genre(all_reviews, genre_labels)

all_labeled_reviews = compact_labeled_reviews.copy()

# %%
this_user_reviews_labeled = label_reviews_with_genre(user_reviews, genre_labels)

# %%
this_user_genre_counts, this_user_genre_pct = get_user_genre_counts(this_user_reviews_labeled)

# %%
M = compact_genre_pct.values
v = this_user_genre_pct.values

# %%
similarities = cosine_similarity(M.T, v.T).ravel()

# %%
other_users = compact_genre_pct.T.index

# %%
similarity_ranker = pd.DataFrame({'other_users': other_users, 'genre_similarity': similarities})
similarity_ranker = similarity_ranker.sort_values(by = 'genre_similarity', ascending = False)
similarity_ranker.head(10)
# Out:
#                    other_users  genre_similarity
# 2675     1741426-odai-al-saeed          0.954290
# 8715   86266847-ammit-p-chawda          0.942506
# 3919             25664045-gary          0.941953
# 485     10907075-mustafa-hasan          0.940251
# 8284             7747793-rahul          0.938931
# 268   104930325-andrew-padilla          0.937633
# 1757    14202578-obied-alahmed          0.937579
# 3139            19839938-kaveh          0.935680
# 7752    69159766-mekhala-bhatt          0.934362
# 92             10179929-sanjay          0.932416

# %%
similarity_ranker['score'] = similarity_ranker['genre_similarity']
similarity_ranker = similarity_ranker.set_index("other_users")
similarity_ranker.head()
# Out:
#                          genre_similarity     score
# other_users
# 1741426-odai-al-saeed            0.954290  0.954290
# 86266847-ammit-p-chawda          0.942506  0.942506
# 25664045-gary                    0.941953  0.941953
# 10907075-mustafa-hasan           0.940251  0.940251
# 7747793-rahul                    0.938931  0.938931

# %%
'16562982-ahmad-khater' in main_user_item_matrix.index
# Out:
# True

# %%
def get_recommendation_from_top(ranker, user_item_matrix = main_user_item_matrix, num_reviewers = 50):
    top_n = get_top_n_reviewers(ranker, num_reviewers)
    experts = top_n.index
    amount_of_say = top_n['score_normed']

    """ maybe write this as another atom func """
    # user_item_matrix for top reviewers of this genre
    expert_user_item_matrix = get_expert_user_item_matrix(user_item_matrix, top_n.index)
    adjusted_expert_user_item_matrix = center_user_item_matrix(expert_user_item_matrix)
    
    adjusted_expert_ratings = get_expert_ratings(adjusted_expert_user_item_matrix, top_n)
    adjusted_expert_ratings[['expert_wavg_rating',f'experts_who_read_out_of_{num_reviewers}']] = [avg_expert_rating(book, top_n, expert_user_item_matrix) for book in adjusted_expert_ratings.index]

    return adjusted_expert_ratings

# %%
ratings_for_me = get_recommendation_from_top(similarity_ranker)

# %%
ratings_for_me.head(30)
# Out:
#                                                     expert_metric  \
# title
# The Outsider                                             0.070943
# The Master and Margarita                                 0.068116
# The Heart of a Dog                                       0.065169
# The 7 Habits of Highly Effective People: Powerf...       0.057079
# How to Stop Worrying and Start Living                    0.056167
# Me Talk Pretty One Day                                   0.052101
# The Laws of Human Nature                                 0.050922
# The Body Keeps the Score: Brain, Mind, and Body...       0.049385
# Death of a Salesman                                      0.049350
# The Tyranny of Merit: What's Become of the Comm...       0.047535
# The Origins of Totalitarianism                           0.047231
# Strange Tales from a Chinese Studio                      0.045088
# Think and Grow Rich                                      0.045074
# Notes from Underground                                   0.043391
# My Uncle Oswald                                          0.041920
# The 7 Habits of Highly Effective People                  0.041317
# The Art of Travel                                        0.038962
# Atomic Habits: An Easy & Proven Way to Build Go...       0.036509
# The Intelligent Investor                                 0.035847
# A Moveable Feast                                         0.035775
# The Plague                                               0.035733
# The Post Office                                          0.034769
# Art Matters: Because Your Imagination Can Chang...       0.032357
# How Proust Can Change Your Life                          0.032187
# The Conference of the Birds                              0.032176
# Status Anxiety                                           0.031702
# When Breath Becomes Air                                  0.029734
# A Thousand Splendid Suns                                 0.029456
# A Very Easy Death                                        0.029394
# 1Q84: Book Three                                         0.027552
#
#                                                     expert_wavg_rating  \
# title
# The Outsider                                                  5.000000
# The Master and Margarita                                      5.000000
# The Heart of a Dog                                            5.000000
# The 7 Habits of Highly Effective People: Powerf...            5.000000
# How to Stop Worrying and Start Living                         4.662519
# Me Talk Pretty One Day                                        4.003652
# The Laws of Human Nature                                      5.000000
# The Body Keeps the Score: Brain, Mind, and Body...            5.000000
# Death of a Salesman                                           5.000000
# The Tyranny of Merit: What's Become of the Comm...            5.000000
# The Origins of Totalitarianism                                5.000000
# Strange Tales from a Chinese Studio                           5.000000
# Think and Grow Rich                                           5.000000
# Notes from Underground                                        5.000000
# My Uncle Oswald                                               5.000000
# The 7 Habits of Highly Effective People                       5.000000
# The Art of Travel                                             4.657975
# Atomic Habits: An Easy & Proven Way to Build Go...            4.490502
# The Intelligent Investor                                      4.000000
# A Moveable Feast                                              5.000000
# The Plague                                                    4.495351
# The Post Office                                               5.000000
# Art Matters: Because Your Imagination Can Chang...            4.502309
# How Proust Can Change Your Life                               5.000000
# The Conference of the Birds                                   4.008958
# Status Anxiety                                                4.668140
# When Breath Becomes Air                                       5.000000
# A Thousand Splendid Suns                                      5.000000
# A Very Easy Death                                             5.000000
# 1Q84: Book Three                                              5.000000
#
#                                                     experts_who_read_out_of_50
# title
# The Outsider                                                               2.0
# The Master and Margarita                                                   2.0
# The Heart of a Dog                                                         2.0
# The 7 Habits of Highly Effective People: Powerf...                         3.0
# How to Stop Worrying and Start Living                                      3.0
# Me Talk Pretty One Day                                                     3.0
# The Laws of Human Nature                                                   2.0
# The Body Keeps the Score: Brain, Mind, and Body...                         2.0
# Death of a Salesman                                                        2.0
# The Tyranny of Merit: What's Become of the Comm...                         1.0
# The Origins of Totalitarianism                                             1.0
# Strange Tales from a Chinese Studio                                        1.0
# Think and Grow Rich                                                        2.0
# Notes from Underground                                                     1.0
# My Uncle Oswald                                                            1.0
# The 7 Habits of Highly Effective People                                    2.0
# The Art of Travel                                                          3.0
# Atomic Habits: An Easy & Proven Way to Build Go...                         2.0
# The Intelligent Investor                                                   1.0
# A Moveable Feast                                                           1.0
# The Plague                                                                 2.0
# The Post Office                                                            1.0
# Art Matters: Because Your Imagination Can Chang...                         2.0
# How Proust Can Change Your Life                                            2.0
# The Conference of the Birds                                                2.0
# Status Anxiety                                                             3.0
# When Breath Becomes Air                                                    1.0
# A Thousand Splendid Suns                                                   2.0
# A Very Easy Death                                                          1.0
# 1Q84: Book Three                                                           1.0

# %%
centered_zscore_matrix.head()
# Out:
#                    "A Problem from Hell": America and the Age of Genocide  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    "Don't You Know Who I Am?": How to Stay Sane in an Era of Narcissism, Entitlement, and Incivility  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    "Stand Back," Said the Elephant, "I'm Going to Sneeze!"  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    "Surely You're Joking, Mr. Feynman!": Adventures of a Curious Character  \
# user_id
# 1-otis-chandler                                             0.438354
# 10001905-lynn                                               0.000000
# 100019622-vonda                                             0.000000
# 100022104-jasmine                                           0.000000
# 10010399-kathleen                                           0.000000
#
#                    #ACCELERATE: Manifesto for an Accelerationist Politics  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    #NaNoWri War Z, Hugh Howey Must Die  'Tis the Damn Season  \
# user_id
# 1-otis-chandler                                    0.0                   0.0
# 10001905-lynn                                      0.0                   0.0
# 100019622-vonda                                    0.0                   0.0
# 100022104-jasmine                                  0.0                   0.0
# 10010399-kathleen                                  0.0                   0.0
#
#                    (Not that You Asked): Rants, Exploits, and Obsessions  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    ... But I'm NOT Racist!: Tools for Well-Meaning Whites  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    ...And Ladies of the Club  ...  gods with a little g  \
# user_id                                       ...
# 1-otis-chandler                          0.0  ...                   0.0
# 10001905-lynn                            0.0  ...                   0.0
# 100019622-vonda                          0.0  ...                   0.0
# 100022104-jasmine                        0.0  ...                   0.0
# 10010399-kathleen                        0.0  ...                   0.0
#
#                    iGen: Why Today’s Super-Connected Kids Are Growing Up Less Rebellious, More Tolerant, Less Happy--and Completely Unprepared for Adulthood--and What That Means for the Rest of Us  \
# user_id
# 1-otis-chandler                                                  0.0
# 10001905-lynn                                                    0.0
# 100019622-vonda                                                  0.0
# 100022104-jasmine                                                0.0
# 10010399-kathleen                                                0.0
#
#                    phineas gage  the prophet  unSweetined  \
# user_id
# 1-otis-chandler             0.0          0.0          0.0
# 10001905-lynn               0.0          0.0          0.0
# 100019622-vonda             0.0          0.0          0.0
# 100022104-jasmine           0.0          0.0          0.0
# 10010399-kathleen           0.0          0.0          0.0
#
#                    ट्वेल्थ फेल | Twelfth Fail | 12th Fail  \
# user_id
# 1-otis-chandler                                       0.0
# 10001905-lynn                                         0.0
# 100019622-vonda                                       0.0
# 100022104-jasmine                                     0.0
# 10010399-kathleen                                     0.0
#
#                    ठीक तुम्हारे पीछे [Theek Tumhare Peechhe]  \
# user_id
# 1-otis-chandler                                          0.0
# 10001905-lynn                                            0.0
# 100019622-vonda                                          0.0
# 100022104-jasmine                                        0.0
# 10010399-kathleen                                        0.0
#
#                    はぴまり~Happy Marriage!?~ 1  バッカーノ！The Rolling Bootlegs  \
# user_id
# 1-otis-chandler                         0.0                         0.0
# 10001905-lynn                           0.0                         0.0
# 100019622-vonda                         0.0                         0.0
# 100022104-jasmine                       0.0                         0.0
# 10010399-kathleen                       0.0                         0.0
#
#                    默读 [Mo Du] The Light in the Night
# user_id
# 1-otis-chandler                                  0.0
# 10001905-lynn                                    0.0
# 100019622-vonda                                  0.0
# 100022104-jasmine                                0.0
# 10010399-kathleen                                0.0
#
# [5 rows x 16576 columns]

# %% [markdown]
# ### Find users with similar taste/ratings

# %%
def get_title_zscore_dict(ex_title, books_rating_stats = books_rating_stats):
    z_score_cols = ['5_zscore', '4_zscore', '3_zscore', '2_zscore', '1_zscore']
    rating_values = [5, 4, 3, 2, 1]

    title_zscores = books_rating_stats[books_rating_stats.title == ex_title][z_score_cols].values.ravel()
    res_dict = {r: z for r, z in zip(rating_values, title_zscores)}

    return res_dict

def get_single_title_rating_zscore(title, rating):
    assert rating in {1,2,3,4,5}, "Rating must be an int from 1-5"
    
    zscore_dict = get_title_zscore_dict(title)
    if zscore_dict:
        res = zscore_dict[rating]
        return res

    return -1

def get_zscore_ratings_for_title_list(titles, ratings):
    res = [get_single_title_rating_zscore(title, rating) for title, rating in zip(titles, ratings)]
    return res

# %%
user_books = user_reviews.title.unique()
user_reviews['zscore_normed_rating'] = get_zscore_ratings_for_title_list(user_reviews.title, user_reviews.rating)
user_reviews.head()
# Out:
#      user_id                                    title_id  \
# 0  155041466             1052.The_Richest_Man_in_Babylon
# 1  155041466  4866.How_to_Stop_Worrying_and_Start_Living
# 2  155041466                               61439040-1984
# 3  155041466                51893.Thus_Spoke_Zarathustra
# 4  155041466                       6708.The_Power_of_Now
#
#                                                title  rating  votes  \
# 0                         The Richest Man in Babylon       4      0
# 1  How to Stop Worrying and Start Living: Time-Te...       4      0
# 2                                               1984       5      0
# 3                             Thus Spoke Zarathustra       4      0
# 4  The Power of Now: A Guide to Spiritual Enlight...       5      0
#
#    zscore_normed_rating
# 0             -0.244134
# 1             -0.163792
# 2             -1.000000
# 3             -0.069174
# 4              0.811980

# %%
centered_zscore_matrix_T = centered_zscore_matrix.T
reduced_item_user_matrix = centered_zscore_matrix_T[centered_zscore_matrix_T.index.isin(user_books)]

# %%
user_zscores_normed = user_reviews[['title', 'zscore_normed_rating']]
user_zscores_normed = user_zscores_normed[user_zscores_normed.zscore_normed_rating != -1]
user_zscores_normed['zscore_normed_rating'] = user_zscores_normed['zscore_normed_rating'] - np.mean(user_zscores_normed['zscore_normed_rating'])
user_zscores_normed = user_zscores_normed.set_index('title')
user_zscores_normed.columns = [user_id]
user_zscores_normed
# Out:
#                                                     155041466
# title
# The Richest Man in Babylon                          -0.386553
# How to Stop Worrying and Start Living: Time-Tes...  -0.306211
# Thus Spoke Zarathustra                              -0.211592
# The Power of Now: A Guide to Spiritual Enlighte...   0.669562
# Memories, Dreams, Reflections                        0.676801
# The 48 Laws of Power                                -0.236962
# The Prince                                           0.017762
# Life of Pi                                          -0.084859
# The Plague                                          -1.268756
# How to Win Friends & Influence People                0.654311
# The Catcher in the Rye                               0.032281
# The Art of War                                       0.928717
# Brave New World                                      0.873131
# The Stranger                                        -0.030867
# Man’s Search for Meaning                             0.606221
# Crime and Punishment                                -0.441800
# The Power of Habit: Why We Do What We Do in Lif...   0.801151
# The Martian                                         -0.669115
# All the Light We Cannot See                          0.645326
# Relentless: From Good to Great to Unstoppable       -0.106376
# The Adventures of Tom Sawyer                        -0.061301
# The Myth of Sisyphus                                -0.345288
# 12 Rules for Life: An Antidote to Chaos              0.783463
# Educated                                            -3.313910
# The Laws of Human Nature                             0.589254
# Can't Hurt Me: Master Your Mind and Defy the Odds   -0.453185
# Range: Why Generalists Triumph in a Specialized...  -0.291743
# The Boy, the Mole, the Fox and the Horse             0.421115
# In Five Years                                        0.083333
# The Midnight Library                                -0.121481
# JFK: Coming Of Age In The American Century, 191...   0.547575

# %%
def remove_users_who_have_no_opinion(reduced_item_user_matrix):
    M = reduced_item_user_matrix.T
    M = M.loc[~(M == 0).all(axis=1)]
    return M.T

# %%
user_specific_matrix = remove_users_who_have_no_opinion(reduced_item_user_matrix)
user_specific_matrix_joined = user_specific_matrix.merge(user_zscores_normed, left_index = True,
                                                                                      right_index= True)

user_specific_matrix_joined.head()
# Out:
#                                                    100759205-kat  \
# 12 Rules for Life: An Antidote to Chaos                      0.0
# All the Light We Cannot See                                  0.0
# Brave New World                                              0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds            0.0
# Crime and Punishment                                         0.0
#
#                                                    10077465-anurag-vaishnav  \
# 12 Rules for Life: An Antidote to Chaos                            0.000000
# All the Light We Cannot See                                        1.161975
# Brave New World                                                    0.000000
# Can't Hurt Me: Master Your Mind and Defy the Odds                  0.000000
# Crime and Punishment                                               0.000000
#
#                                                    100778714-andrea-hartmann  \
# 12 Rules for Life: An Antidote to Chaos                                  0.0
# All the Light We Cannot See                                              0.0
# Brave New World                                                          0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                        0.0
# Crime and Punishment                                                     0.0
#
#                                                    100790884-abby-moore  \
# 12 Rules for Life: An Antidote to Chaos                         0.00000
# All the Light We Cannot See                                    -0.91693
# Brave New World                                                 0.00000
# Can't Hurt Me: Master Your Mind and Defy the Odds               0.00000
# Crime and Punishment                                            0.00000
#
#                                                    100807586-nellian  \
# 12 Rules for Life: An Antidote to Chaos                          0.0
# All the Light We Cannot See                                      0.0
# Brave New World                                                  0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                0.0
# Crime and Punishment                                             0.0
#
#                                                    101358081-imme-van-gorp  \
# 12 Rules for Life: An Antidote to Chaos                                0.0
# All the Light We Cannot See                                            0.0
# Brave New World                                                        0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                      0.0
# Crime and Punishment                                                   0.0
#
#                                                    101693182-tharindu-dissanayake  \
# 12 Rules for Life: An Antidote to Chaos                                       0.0
# All the Light We Cannot See                                                   0.0
# Brave New World                                                               0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                             0.0
# Crime and Punishment                                                          0.0
#
#                                                    10171516-jessica  \
# 12 Rules for Life: An Antidote to Chaos                    0.000000
# All the Light We Cannot See                               -0.317322
# Brave New World                                            0.000000
# Can't Hurt Me: Master Your Mind and Defy the Odds          0.000000
# Crime and Punishment                                       0.000000
#
#                                                    101718720-kamal  \
# 12 Rules for Life: An Antidote to Chaos                        0.0
# All the Light We Cannot See                                    0.0
# Brave New World                                                0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds              0.0
# Crime and Punishment                                           0.0
#
#                                                    10179929-sanjay  ...  \
# 12 Rules for Life: An Antidote to Chaos                        0.0  ...
# All the Light We Cannot See                                    0.0  ...
# Brave New World                                                0.0  ...
# Can't Hurt Me: Master Your Mind and Defy the Odds              0.0  ...
# Crime and Punishment                                           0.0  ...
#
#                                                    9711335-mallory  \
# 12 Rules for Life: An Antidote to Chaos                        0.0
# All the Light We Cannot See                                    0.0
# Brave New World                                                0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds              0.0
# Crime and Punishment                                           0.0
#
#                                                    972022-emily  \
# 12 Rules for Life: An Antidote to Chaos                     0.0
# All the Light We Cannot See                                 0.0
# Brave New World                                             0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds           0.0
# Crime and Punishment                                        0.0
#
#                                                    974210-erik-graff  \
# 12 Rules for Life: An Antidote to Chaos                          0.0
# All the Light We Cannot See                                      0.0
# Brave New World                                                  0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                0.0
# Crime and Punishment                                             0.0
#
#                                                    97513431-tamoghna-biswas  \
# 12 Rules for Life: An Antidote to Chaos                                 0.0
# All the Light We Cannot See                                             0.0
# Brave New World                                                         0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                       0.0
# Crime and Punishment                                                    0.0
#
#                                                    97546350-giorgia-reads  \
# 12 Rules for Life: An Antidote to Chaos                               0.0
# All the Light We Cannot See                                           0.0
# Brave New World                                                       0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds                     0.0
# Crime and Punishment                                                  0.0
#
#                                                    98090277-juju  \
# 12 Rules for Life: An Antidote to Chaos                      0.0
# All the Light We Cannot See                                  0.0
# Brave New World                                              0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds            0.0
# Crime and Punishment                                         0.0
#
#                                                    9882308-atlas  \
# 12 Rules for Life: An Antidote to Chaos                      0.0
# All the Light We Cannot See                                  0.0
# Brave New World                                              0.0
# Can't Hurt Me: Master Your Mind and Defy the Odds            0.0
# Crime and Punishment                                         0.0
#
#                                                    99413969-simon-ri  \
# 12 Rules for Life: An Antidote to Chaos                     0.000000
# All the Light We Cannot See                                 0.000000
# Brave New World                                             0.000000
# Can't Hurt Me: Master Your Mind and Defy the Odds           0.106675
# Crime and Punishment                                        0.000000
#
#                                                    996039-rosieface  155041466
# 12 Rules for Life: An Antidote to Chaos                         0.0   0.783463
# All the Light We Cannot See                                     0.0   0.645326
# Brave New World                                                 0.0   0.873131
# Can't Hurt Me: Master Your Mind and Defy the Odds               0.0  -0.453185
# Crime and Punishment                                            0.0  -0.441800
#
# [5 rows x 599 columns]

# %%
def elements_in_both_arr(a, b):
    # Create mask for non-zero values in both arrays
    mask = (a != 0) & (b != 0)
    
    # Apply mask to filter both arrays
    a_filtered = a[mask]
    b_filtered = b[mask]

    return a_filtered, b_filtered

def cosine_similarity_2_arrs(a, b):
    res = cosine_similarity(a.reshape(1,-1), b.reshape(1,-1))[0,0]
    return res

def cos_similarity(arr1, arr2):
    a_filtered, b_filtered = elements_in_both_arr(arr1, arr2)

    res = cosine_similarity_2_arrs(a_filtered, b_filtered)
    sample_size = len(a_filtered)
    
    return res, sample_size

# %%
arr1 = user_specific_matrix_joined.iloc[:, -1].values
arr2 = user_specific_matrix_joined.iloc[:, -1].values

# %%
cos, s = cos_similarity(arr1, arr2)

# %%
# Assume user_specific_matrix_joined is your DataFrame
arr2 = user_specific_matrix_joined.iloc[:, -1].values  # last column
results = {}

for col in user_specific_matrix_joined.columns[:-1]:  # all columns except the last
    similarity, sample_size = cos_similarity(user_specific_matrix_joined[col].values, arr2)
    results[col] = {
        'cosine_similarity': similarity,
        'sample_size': sample_size
    }

# Convert to DataFrame if needed
results_user_specific_matrix_joined = pd.DataFrame.from_dict(results, orient='index')

# %%
user_similarity_ranking = results_user_specific_matrix_joined.sort_values(by = 'sample_size', ascending = False)
user_similarity_ranking['score'] = user_similarity_ranking['cosine_similarity'] * user_similarity_ranking['sample_size']
user_similarity_ranking = user_similarity_ranking.sort_values('score', ascending=False)

# %%
user_similarity_ranking.head(20)
# Out:
#                                       cosine_similarity  sample_size     score
# 101693182-tharindu-dissanayake                 0.765807            5  3.829036
# 27788046-sean-barrs                            0.519788            7  3.638516
# 5431458-henry-avila                            0.980080            3  2.940241
# 30181442-yun                                   0.443001            6  2.658006
# 124132123-lisa-of-troy                         0.277684            8  2.221475
# 42130592-chai-thelibrairie-on-tiktok           0.999983            2  1.999967
# 14002983-charlotte-may                         0.998367            2  1.996734
# 46308842-maria-clara                           0.997412            2  1.994825
# 2120682-eden-prosper                           0.992717            2  1.985433
# 38342050-ying-ying                             0.986776            2  1.973552
# 597461-elyse-walters                           0.493144            4  1.972576
# 67861858-pakinam-mahmoud                       0.966429            2  1.932858
# 5032725-debra                                  0.966092            2  1.932184
# 4047037-bushra-omar                            0.949966            2  1.899932
# 47417894-laura-noggle                          0.938900            2  1.877799
# 2795921-justin                                 0.889974            2  1.779948
# 25605420-apoorva                               0.588984            3  1.766952
# 51989964-lena-trak                             0.813751            2  1.627501
# 12772859-mischas                               0.789340            2  1.578680
# 19283284-vit-babenco                           0.480601            3  1.441803

# %%
ratings_for_me_2 = get_recommendation_from_top(user_similarity_ranking, num_reviewers = 20)

# %%
ratings_for_me_2.head(10)
# Out:
#                                                     expert_metric  \
# title
# To Kill a Mockingbird                                    0.243911
# The Return of the King                                   0.242299
# A Clash of Kings                                         0.234275
# The Vegetarian                                           0.227397
# The Priory of the Orange Tree                            0.208431
# The Book of Hope: A Survival Guide for Trying T...       0.200505
# The Song of Achilles                                     0.198605
# A Gentleman in Moscow                                    0.196139
# Charlie and the Chocolate Factory                        0.191877
# The Picture of Dorian Gray                               0.190040
#
#                                                     expert_wavg_rating  \
# title
# To Kill a Mockingbird                                         5.000000
# The Return of the King                                        5.000000
# A Clash of Kings                                              5.000000
# The Vegetarian                                                4.809098
# The Priory of the Orange Tree                                 5.000000
# The Book of Hope: A Survival Guide for Trying T...            5.000000
# The Song of Achilles                                          4.479504
# A Gentleman in Moscow                                         5.000000
# Charlie and the Chocolate Factory                             4.553865
# The Picture of Dorian Gray                                    4.613224
#
#                                                     experts_who_read_out_of_20
# title
# To Kill a Mockingbird                                                      3.0
# The Return of the King                                                     3.0
# A Clash of Kings                                                           3.0
# The Vegetarian                                                             4.0
# The Priory of the Orange Tree                                              3.0
# The Book of Hope: A Survival Guide for Trying T...                         3.0
# The Song of Achilles                                                       5.0
# A Gentleman in Moscow                                                      4.0
# Charlie and the Chocolate Factory                                          4.0
# The Picture of Dorian Gray                                                 5.0
