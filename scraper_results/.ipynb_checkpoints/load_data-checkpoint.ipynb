# %%
import pandas as pd

books = pd.read_parquet("Business_books.parquet")
books
# Out:
#                                                title       author  \
# 0  Good to Great: Why Some Companies Make the Lea...  Jim Collins
# 1  Zero to One: Notes on Startups, or How to Buil...  Peter Thiel
# 2                                   The Lean Startup    Eric Ries
#
#                                               genres  page_count publish_date  \
# 0  [Business, Nonfiction, Leadership, Management,...         300   2001-11-01
# 1  [Business, Nonfiction, Entrepreneurship, Self ...         195   2014-09-16
# 2  [Business, Nonfiction, Entrepreneurship, Manag...         299   2011-01-01
#
#    rating  num_ratings  num_reviews  five_stars  four_stars  three_stars  \
# 0    4.12       269813         6604      115262       92436        46877
# 1    4.15       373228         9728      179195      113089        53536
# 2    4.11       351595         4876      157734      114232        52812
#
#    two_stars  one_star
# 0       9460      5778
# 1      14076     13332
# ...

# %%
reviews = pd.read_parquet("Art_reviews.parquet")
reviews
# Out:
#                                                 title  \
# 0                                      Ways of Seeing
# 1                                      Ways of Seeing
# 2                                      Ways of Seeing
# 3                                      Ways of Seeing
# 4                                      Ways of Seeing
# 5                                      Ways of Seeing
# 6                                      Ways of Seeing
# 7                                      Ways of Seeing
# 8                                      Ways of Seeing
# 9                                      Ways of Seeing
# 10                                   The Story of Art
# 11                                   The Story of Art
# 12                                   The Story of Art
# 13                                   The Story of Art
# 14                                   The Story of Art
# 15                                   The Story of Art
# ...
